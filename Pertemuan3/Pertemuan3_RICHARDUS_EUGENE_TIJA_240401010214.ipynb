# %%
import pandas as pd
import numpy as np
from scipy.stats import mstats

# Load the dataset with the correct semicolon separator
df = pd.read_csv('/content/housing_dirty.csv', sep=';')

# Display the first few rows to verify
display(df.head())
# Out:
#    id  luas_m2  harga_juta   kota  kamar  tahun_bangun kondisi
# 0   1   2970.0     10840.0  jogja   20.0          2000    baik
# 1   2   2540.0      7610.0  Medan    NaN          1995   Bagus
# 2   3   2497.0      8950.0  Depok    NaN          1983    baik
# 3   4    497.0      1780.0    YGY   50.0          2013    baik
# 4   5   1334.0      4240.0  Medan   50.0          2004  Sedang

# %%
# STEP 0 — Load & eksplorasi awal
df = pd.read_csv('housing_dirty.csv', sep=';')
print('Shape awal:', df.shape)
print(df.isnull().sum())
# Out:
# Shape awal: (130, 7)
# id               0
# luas_m2         18
# harga_juta      17
# kota             0
# kamar           10
# tahun_bangun     0
# kondisi          0
# dtype: int64

# %%
# STEP 1 — Hapus Duplikat
df.drop_duplicates(inplace=True)
print('Setelah hapus duplikat:', df.shape)
# Out:
# Setelah hapus duplikat: (130, 7)

# %%
# STEP 2 — Normalisasi String
df['kota'] = df['kota'].str.strip().str.title()
df['kondisi'] = df['kondisi'].str.strip().str.lower()

# %%
# STEP 3 — Imputasi Missing Values
df['luas_m2'] = df['luas_m2'].fillna(df['luas_m2'].median())
df['harga_juta'] = df['harga_juta'].fillna(df['harga_juta'].median())
df['kamar'] = df['kamar'].fillna(df['kamar'].mode()[0])

# %%
# STEP 4 — Tangani Outlier (IQR Fence)
for col in ['harga_juta', 'luas_m2', 'tahun_bangun']:
    Q1, Q3 = df[col].quantile([0.25, 0.75])
    IQR = Q3 - Q1
    df[col] = df[col].clip(Q1-1.5*IQR, Q3+1.5*IQR)

# %%
# STEP 5 — Validasi & Ekspor
assert df.isnull().sum().sum() == 0, 'Masih ada missing!'
assert df.duplicated().sum() == 0, 'Masih ada duplikat!'
print('Shape akhir:', df.shape)
df.to_csv('housing_clean.csv', index=False)
print('Dataset bersih tersimpan!')
# Out:
# Shape akhir: (130, 7)
# Dataset bersih tersimpan!

# %% [markdown]
# ### STEP 6 — Akses API JSONPlaceholder
# Tahap terakhir adalah mengambil data dari API publik dan mengonversinya ke dalam DataFrame.

# %%
import pandas as pd
import requests

# Mengambil data dari JSONPlaceholder (contoh: endpoint /posts)
url = 'https://jsonplaceholder.typicode.com/posts'
response = requests.get(url)

# Cek apakah request berhasil
if response.status_code == 200:
    data_api = response.json()
    df_api = pd.DataFrame(data_api)
    print('Berhasil mengambil data dari API!')
    display(df_api.head())
else:
    print(f'Gagal mengambil data. Status code: {response.status_code}')
# Out:
# Berhasil mengambil data dari API!
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

# %%
import pandas as pd

# Mengatur agar pandas menampilkan semua baris
pd.set_option('display.max_rows', 150)

# Menampilkan seluruh dataset
display(df)
# Out:
#       id  luas_m2  harga_juta        kota  kamar  tahun_bangun         kondisi
# 0      1  2970.00     10840.0       Jogja   20.0        2000.0            baik
# 1      2  2540.00      7610.0       Medan   10.0        1995.0           bagus
# 2      3  2497.00      8950.0       Depok   10.0        1983.0            baik
# 3      4   497.00      1780.0         Ygy   50.0        2013.0            baik
# 4      5  1334.00      4240.0       Medan   50.0        2004.0          sedang
# 5      6  1533.00      8140.0     Jakarta   10.0        2006.0          sedang
# 6      7  1143.00      6550.0     Jakarta   30.0        2011.0            baik
# 7      8  1938.00      3330.0  Yogyakarta   10.0        1989.0     baik sekali
# 8      9   812.00      3070.0  Yogyakarta   10.0        1996.0          sedang
# 9     10   691.00      2370.0     Bandung   50.0        1980.0            baik
# 10    11  1596.00      6300.0    Surabaya   60.0        2023.0          sedang
# 11    12   812.00      3450.0         Dpk   50.0        2008.0            baik
# 12    13   842.00      3820.0         Sby   20.0        2006.0          sedang
# 13    14  1938.00      8020.0     Jakarta   30.0        2004.0            baik
# 14    15  1938.00      5030.0    Makassar   60.0        2016.0          sedang
# 15    16  2005.00      4950.0         Mdn   60.0        1994.0            baik
# 16    17  3033.00     10430.0     Bandung   40.0        1993.0          sedang
# 17    18   515.00      1830.0  Yogyakarta   60.0        2020.0          sedang
# 18    19  1938.00      6550.0     Bandung   10.0        2015.0           rusak
# 19    20  2977.00      6550.0    Surabaya   10.0        2009.0            baik
# 20    21  1950.00      5110.0       Medan   10.0        2014.0          sedang
# 21    22  1938.00      6550.0    Semarang   20.0        1984.0            baik
# 22    23  3009.00      6550.0    Semarang   50.0        2000.0            baik
# 23    24   534.00      1560.0       Medan   40.0        2002.0          sedang
# 24    25   977.00      3490.0  Yogyakarta   50.0        1995.0          sedang
# 25    26  1938.00      9160.0    Semarang   40.0        2013.0     baik sekali
# 26    27  1138.00     -4227.5     Bandung   60.0        1993.0     baik sekali
# 27    28  2488.00      9550.0  Yogyakarta   60.0        1993.0            baik
# 28    29  2263.00      6640.0       Medan   30.0        2016.0            baik
# 29    30  1103.00      4550.0  Yogyakarta   60.0        1986.0            baik
# 30    31  1894.00      8190.0       Jogja   60.0        2012.0          sedang
# 31    32   679.00      1950.0    Makassar   20.0        1980.0           rusak
# 32    33   774.00      2370.0       Medan   50.0        2007.0           cukup
# 33    34  2886.00     15980.0     Jakarta   40.0        2016.0           rusak
# 34    35  2949.00      9340.0       Medan   40.0        2017.0            baik
# 35    36  2784.00      8630.0       Medan   10.0        2021.0          sedang
# 36    37  1938.00      6310.0         Smg   40.0        1996.0          sedang
# 37    38   404.00      1700.0         Ygy   60.0        2005.0            baik
# 38    39   691.00      2370.0     Bandung   50.0        1980.0            baik
